# %%
import math
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt

#CSV_PATH = "/kaggle/input/robotic-arm-dataset-multiple-trajectories/robotic_arm_dataset_multiple_trajectories.csv"
CSV_PATH = "/kaggle/input/datasets/meghrajbagde/robotic-arm-dataset-multiple-trajectories/robotic_arm_dataset_multiple_trajectories.csv"
FEATURE_COLS = ["Axis_0_Angle", "Axis_1_Angle", "Axis_2_Angle"]

# We assume the whole dataset is ONE long trajectory.
K_LIST = [10, 50, 100]         # history block lengths to try
H = 10                         # predict next H steps (block)

TRAIN_RATIO = 0.70    # time-based split on blocks: earliest blocks for train
VAL_RATIO = 0.15      # next blocks for val, rest for test

BATCH_SIZE = 256
EPOCHS = 20
LR = 1e-3
WEIGHT_DECAY = 1e-4

HIDDEN = 64
LAYERS = 1
DROPOUT = 0.1

SEED = 42
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# =========================
# 1) Reproducibility
# =========================
def set_seed(seed: int):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(SEED)

def overall_mae(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    return float(np.mean(np.abs(y_true - y_pred)))

def overall_rmse(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    return float(np.sqrt(np.mean((y_true - y_pred) ** 2)))

def per_step_mae(y_true: np.ndarray, y_pred: np.ndarray) -> np.ndarray:
    # (N, H, d) -> (H,)
    return np.mean(np.abs(y_true - y_pred), axis=(0, 2))

# =========================
# 2) Data Loading & Prep
# =========================
df = pd.read_csv(CSV_PATH)
X_raw = df[FEATURE_COLS].to_numpy(dtype=np.float32)  # (T, d)
T, d = X_raw.shape
print(f"Loaded ONE long trajectory: T={T}, d={d}")

# Normalize using TRAIN portion of time.
t_train_end = int(TRAIN_RATIO * T)
eps = 1e-6
mu = X_raw[:t_train_end].mean(axis=0, keepdims=True)
std = X_raw[:t_train_end].std(axis=0, keepdims=True)
X = (X_raw - mu) / (std + eps)  # normalized long trajectory

def compute_num_blocks(T, K, H):
    block_len = K + H
    return (T - block_len) // block_len + 1 if T >= block_len else 0

class BlockDataset(Dataset):
    def __init__(self, X: np.ndarray, K: int, H: int, block_ids: np.ndarray):
        self.X = X
        self.K = K
        self.H = H
        self.block_len = K + H
        self.block_ids = block_ids.astype(np.int64)

    def __len__(self):
        return len(self.block_ids)

    def __getitem__(self, idx):
        bid = int(self.block_ids[idx])
        s = bid * self.block_len
        x = self.X[s : s + self.K]                    # (K,d)
        y = self.X[s + self.K : s + self.K + self.H]  # (H,d)
        return torch.from_numpy(x), torch.from_numpy(y)

# =========================
# 3) Vanilla RNN Model
# =========================
class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, max_len: int = 5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)      # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2, dtype=torch.float32) *
                             (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)   # (1, max_len, d_model)
        self.register_buffer("pe", pe)

    def forward(self, x):
        """
        x: (B, K, d_model)
        """
        K = x.size(1)
        return x + self.pe[:, :K, :]

class TransformerDirect(nn.Module):
    def __init__(
        self,
        d: int,            # input dimension
        H: int,            # horizon
        d_model: int = 64,
        nhead: int = 4,
        num_layers: int = 2,
        dim_feedforward: int = 128,
        dropout: float = 0.1,
    ):
        super().__init__()
        self.H = H
        self.d = d

        # Project input features -> transformer model dimension
        self.input_proj = nn.Linear(d, d_model)

        self.pos_encoder = PositionalEncoding(d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,          # VERY IMPORTANT so we can use (B, K, d_model)
        )
        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_layers
        )

        self.dropout = nn.Dropout(dropout)
        self.fc_out = nn.Linear(d_model, H * d)

    def forward(self, x):
        """
        x: (B, K, d)
        returns: (B, H, d)
        """
        # (B, K, d_model)
        x = self.input_proj(x)
        x = self.pos_encoder(x)

        # Transformer encoder
        enc = self.encoder(x)          # (B, K, d_model)

        # Use last time step as "summary" representation
        last = enc[:, -1, :]           # (B, d_model)
        last = self.dropout(last)

        out = self.fc_out(last)        # (B, H * d)
        return out.view(-1, self.H, self.d)

class RNNDirect(nn.Module):
    def __init__(self, d: int, hidden: int, layers: int, H: int, dropout: float):
        super().__init__()
        self.H = H
        self.d = d
        self.rnn = nn.RNN(
            input_size=d,
            hidden_size=hidden,
            num_layers=layers,
            batch_first=True,
            dropout=dropout if layers > 1 else 0.0
        )
        self.drop = nn.Dropout(dropout) if dropout > 0 else nn.Identity()
        self.fc = nn.Linear(hidden, H * d)

    def forward(self, x):
        # x: (B,K,d)
        out, _ = self.rnn(x)
        last = out[:, -1, :]
        last = self.drop(last)
        y = self.fc(last)               # (B, H*d)
        return y.view(-1, self.H, self.d)

# =========================
# 4) Training & Evaluation
# =========================
def eval_mse(model, loader):
    model.eval()
    loss_fn = nn.MSELoss()
    losses = []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)
            pred = model(xb)
            losses.append(loss_fn(pred, yb).item())
    return float(np.mean(losses)) if losses else float("nan")

def collect_predictions(model, loader):
    model.eval()
    preds, trues = [], []
    with torch.no_grad():
        for xb, yb in loader:
            pred = model(xb.to(DEVICE)).cpu().numpy()
            preds.append(pred)
            trues.append(yb.numpy())
    return np.concatenate(trues, axis=0), np.concatenate(preds, axis=0)

results = []
histories = {}
step_curves = {}

for K in K_LIST:
    n_blocks = compute_num_blocks(T, K, H)
    if n_blocks <= 5:
        print(f"[SKIP] K={K}: too few blocks ({n_blocks}).")
        continue

    n_train = int(TRAIN_RATIO * n_blocks)
    n_val = int(VAL_RATIO * n_blocks)
    n_test = n_blocks - n_train - n_val

    train_block_ids = np.arange(0, n_train)
    val_block_ids = np.arange(n_train, n_train + n_val)
    test_block_ids = np.arange(n_train + n_val, n_blocks)

    train_ds = BlockDataset(X, K, H, train_block_ids)
    val_ds   = BlockDataset(X, K, H, val_block_ids)
    test_ds  = BlockDataset(X, K, H, test_block_ids)

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
    test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

    model = TransformerDirect(
        d=d,
        H=H,
        d_model=128,         # you can tune these
        nhead=8,
        num_layers=3,
        dim_feedforward=128,
        dropout=DROPOUT,
    ).to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    loss_fn = nn.MSELoss()

    best_val = float("inf")
    best_state = None
    train_mse_hist, val_mse_hist = [], []

    for ep in range(1, EPOCHS + 1):
        model.train()
        batch_losses = []
        for xb, yb in train_loader:
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)
            opt.zero_grad()
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            opt.step()
            batch_losses.append(loss.item())

        train_mse = float(np.mean(batch_losses)) if batch_losses else float("nan")
        val_mse = eval_mse(model, val_loader)
        train_mse_hist.append(train_mse)
        val_mse_hist.append(val_mse)

        if val_mse < best_val:
            best_val = val_mse
            best_state = {kk: vv.detach().cpu().clone() for kk, vv in model.state_dict().items()}

        print(f"Transformer | K={K:2d} | Epoch {ep:02d} | train_MSE={train_mse:.6f} | val_MSE={val_mse:.6f} | best={best_val:.6f}")

    model.load_state_dict(best_state)

    y_true, y_pred = collect_predictions(model, test_loader)
    test_mae = overall_mae(y_true, y_pred)
    test_rmse = overall_rmse(y_true, y_pred)
    curve = per_step_mae(y_true, y_pred)  # (H,)

    results.append({
        "K": K,
        "H": H,
        "Blocks_total": n_blocks,
        "Blocks_train": len(train_ds),
        "Blocks_val": len(val_ds),
        "Blocks_test": len(test_ds),
        "Best_Val_MSE": best_val,
        "Test_MAE": test_mae,
        "Test_RMSE": test_rmse,
    })
    histories[K] = {"train_mse": train_mse_hist, "val_mse": val_mse_hist}
    step_curves[K] = curve

results_df = pd.DataFrame(results).sort_values("K").reset_index(drop=True)
print("\n===== Vanilla Transformer Summary (non-overlap blocks) =====")
print(results_df)

# =========================
# 5) Plotting
# =========================
if len(results_df) > 0:
    # (A) Test MAE/RMSE vs K
    
    plt.figure()
    plt.plot(results_df["K"], results_df["Test_MAE"], marker="o", label="Test MAE")
    plt.plot(results_df["K"], results_df["Test_RMSE"], marker="o", label="Test RMSE")
    plt.xlabel("History block length K")
    plt.ylabel("Error (normalized)")
    plt.title(f"Transformer: Test Error vs K (Non-overlapping blocks, H={H})")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # (B) Error growth vs horizon step (MAE per step) for each K
    plt.figure()
    steps = np.arange(1, H + 1)
    for K in results_df["K"].tolist():
        plt.plot(steps, step_curves[K], marker="o", label=f"K={K}")
    plt.xlabel("Horizon step (1..H)")
    plt.ylabel("MAE (normalized)")
    plt.title(f"Transformer: Error Growth vs Horizon (Direct multi-step)")
    plt.legend()
    plt.grid(True)
    plt.show()

    # (C) Training curve for best K by Test_MAE
    # (C-alt) Training curve for all K, one figure per K
    for K_val in results_df["K"].tolist():
        plt.figure()
        plt.plot(histories[K_val]["train_mse"], marker="o", label="Train MSE")
        plt.plot(histories[K_val]["val_mse"], marker="o", label="Val MSE")
        plt.xlabel("Epoch")
        plt.ylabel("MSE")
        plt.title(f"Transformer: Training Curve (K={K_val}, H={H})")
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
# Loaded ONE long trajectory: T=152500, d=3
# Transformer | K=10 | Epoch 01 | train_MSE=0.292760 | val_MSE=0.028837 | best=0.028837
# Transformer | K=10 | Epoch 02 | train_MSE=0.065147 | val_MSE=0.008188 | best=0.008188
# Transformer | K=10 | Epoch 03 | train_MSE=0.049809 | val_MSE=0.004155 | best=0.004155
# Transformer | K=10 | Epoch 04 | train_MSE=0.042200 | val_MSE=0.002953 | best=0.002953
# Transformer | K=10 | Epoch 05 | train_MSE=0.035795 | val_MSE=0.001603 | best=0.001603
# Transformer | K=10 | Epoch 06 | train_MSE=0.030583 | val_MSE=0.001724 | best=0.001603
# Transformer | K=10 | Epoch 07 | train_MSE=0.025839 | val_MSE=0.001124 | best=0.001124
# Transformer | K=10 | Epoch 08 | train_MSE=0.021915 | val_MSE=0.001727 | best=0.001124
# Transformer | K=10 | Epoch 09 | train_MSE=0.019068 | val_MSE=0.001092 | best=0.001092
# Transformer | K=10 | Epoch 10 | train_MSE=0.016664 | val_MSE=0.001136 | best=0.001092
# Transformer | K=10 | Epoch 11 | train_MSE=0.015032 | val_MSE=0.001056 | best=0.001056
# Transformer | K=10 | Epoch 12 | train_MSE=0.014017 | val_MSE=0.001378 | best=0.001056
# Transformer | K=10 | Epoch 13 | train_MSE=0.012971 | val_MSE=0.000852 | best=0.000852
# Transformer | K=10 | Epoch 14 | train_MSE=0.012411 | val_MSE=0.001277 | best=0.000852
# Transformer | K=10 | Epoch 15 | train_MSE=0.011786 | val_MSE=0.001415 | best=0.000852
# Transformer | K=10 | Epoch 16 | train_MSE=0.010935 | val_MSE=0.001506 | best=0.000852
# Transformer | K=10 | Epoch 17 | train_MSE=0.010601 | val_MSE=0.001606 | best=0.000852
# Transformer | K=10 | Epoch 18 | train_MSE=0.010093 | val_MSE=0.001029 | best=0.000852
# Transformer | K=10 | Epoch 19 | train_MSE=0.009756 | val_MSE=0.001461 | best=0.000852
# Transformer | K=10 | Epoch 20 | train_MSE=0.009456 | val_MSE=0.001130 | best=0.000852
# Transformer | K=50 | Epoch 01 | train_MSE=0.665858 | val_MSE=0.159240 | best=0.159240
# Transformer | K=50 | Epoch 02 | train_MSE=0.154774 | val_MSE=0.052313 | best=0.052313
# Transformer | K=50 | Epoch 03 | train_MSE=0.095658 | val_MSE=0.031924 | best=0.031924
# Transformer | K=50 | Epoch 04 | train_MSE=0.073986 | val_MSE=0.020445 | best=0.020445
# Transformer | K=50 | Epoch 05 | train_MSE=0.062466 | val_MSE=0.014554 | best=0.014554
# Transformer | K=50 | Epoch 06 | train_MSE=0.057456 | val_MSE=0.010184 | best=0.010184
# Transformer | K=50 | Epoch 07 | train_MSE=0.053328 | val_MSE=0.007929 | best=0.007929
# Transformer | K=50 | Epoch 08 | train_MSE=0.049575 | val_MSE=0.005055 | best=0.005055
# Transformer | K=50 | Epoch 09 | train_MSE=0.046529 | val_MSE=0.003862 | best=0.003862
# Transformer | K=50 | Epoch 10 | train_MSE=0.043492 | val_MSE=0.003045 | best=0.003045
# Transformer | K=50 | Epoch 11 | train_MSE=0.040607 | val_MSE=0.002269 | best=0.002269
# Transformer | K=50 | Epoch 12 | train_MSE=0.039299 | val_MSE=0.002535 | best=0.002269
# Transformer | K=50 | Epoch 13 | train_MSE=0.037482 | val_MSE=0.002487 | best=0.002269
# Transformer | K=50 | Epoch 14 | train_MSE=0.034762 | val_MSE=0.001571 | best=0.001571
# Transformer | K=50 | Epoch 15 | train_MSE=0.033012 | val_MSE=0.001509 | best=0.001509
# Transformer | K=50 | Epoch 16 | train_MSE=0.031535 | val_MSE=0.001610 | best=0.001509
# Transformer | K=50 | Epoch 17 | train_MSE=0.029964 | val_MSE=0.001404 | best=0.001404
# Transformer | K=50 | Epoch 18 | train_MSE=0.028277 | val_MSE=0.001640 | best=0.001404
# Transformer | K=50 | Epoch 19 | train_MSE=0.026773 | val_MSE=0.001537 | best=0.001404
# Transformer | K=50 | Epoch 20 | train_MSE=0.025337 | val_MSE=0.001447 | best=0.001404
# Transformer | K=100 | Epoch 01 | train_MSE=0.780826 | val_MSE=0.368049 | best=0.368049
# Transformer | K=100 | Epoch 02 | train_MSE=0.244078 | val_MSE=0.129293 | best=0.129293
# Transformer | K=100 | Epoch 03 | train_MSE=0.146236 | val_MSE=0.065344 | best=0.065344
# Transformer | K=100 | Epoch 04 | train_MSE=0.104614 | val_MSE=0.039895 | best=0.039895
# Transformer | K=100 | Epoch 05 | train_MSE=0.082917 | val_MSE=0.029436 | best=0.029436
# Transformer | K=100 | Epoch 06 | train_MSE=0.074683 | val_MSE=0.023896 | best=0.023896
# Transformer | K=100 | Epoch 07 | train_MSE=0.066237 | val_MSE=0.018258 | best=0.018258
# Transformer | K=100 | Epoch 08 | train_MSE=0.061317 | val_MSE=0.013225 | best=0.013225
# Transformer | K=100 | Epoch 09 | train_MSE=0.055519 | val_MSE=0.009019 | best=0.009019
# Transformer | K=100 | Epoch 10 | train_MSE=0.054190 | val_MSE=0.007584 | best=0.007584
# Transformer | K=100 | Epoch 11 | train_MSE=0.053728 | val_MSE=0.006681 | best=0.006681
# Transformer | K=100 | Epoch 12 | train_MSE=0.050695 | val_MSE=0.005111 | best=0.005111
# Transformer | K=100 | Epoch 13 | train_MSE=0.046762 | val_MSE=0.004217 | best=0.004217
# Transformer | K=100 | Epoch 14 | train_MSE=0.044775 | val_MSE=0.004063 | best=0.004063
# Transformer | K=100 | Epoch 15 | train_MSE=0.044131 | val_MSE=0.003819 | best=0.003819
# Transformer | K=100 | Epoch 16 | train_MSE=0.043077 | val_MSE=0.003267 | best=0.003267
# Transformer | K=100 | Epoch 17 | train_MSE=0.041156 | val_MSE=0.002793 | best=0.002793
# Transformer | K=100 | Epoch 18 | train_MSE=0.039966 | val_MSE=0.002688 | best=0.002688
# Transformer | K=100 | Epoch 19 | train_MSE=0.038575 | val_MSE=0.002318 | best=0.002318
# Transformer | K=100 | Epoch 20 | train_MSE=0.036323 | val_MSE=0.002331 | best=0.002318
#
# ===== Vanilla Transformer Summary (non-overlap blocks) =====
#      K   H  Blocks_total  Blocks_train  Blocks_val  Blocks_test  Best_Val_MSE  \
# 0   10  10          7625          5337        1143         1145      0.000852
# 1   50  10          2541          1778         381          382      0.001404
# 2  100  10          1386           970         207          209      0.002318
#
#    Test_MAE  Test_RMSE
# 0  0.023573   0.029742
# 1  0.028128   0.036188
# 2  0.038086   0.048746
